# %%
import openml
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

#openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
benchmark_suite = openml.study.get_suite('OpenML-CC18')  # obtain the benchmark suite

# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(),
                                     sklearn.ensemble.RandomForestClassifier())

for task_id in benchmark_suite.tasks:  # iterate over all tasks

    task = openml.tasks.get_task(task_id) # download the OpenML task
    #X, y = task.get_X_and_y() # get the data (not used in this example)
    openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
    run = openml.runs.run_model_on_task(clf, task) # run classifier on splits (requires API key)
    score = run.get_metric_fn(sklearn.metrics.accuracy_score) # print accuracy score
    print('Data set: %s; Accuracy: %0.2f' % (task.get_dataset().name,score.mean()))
# Out:
# Data set: kr-vs-kp; Accuracy: 0.99
# Data set: letter; Accuracy: 0.94
# Data set: balance-scale; Accuracy: 0.82
# Data set: mfeat-factors; Accuracy: 0.95
# Data set: mfeat-fourier; Accuracy: 0.80
# Data set: breast-w; Accuracy: 0.97
# Data set: mfeat-karhunen; Accuracy: 0.91
# Data set: mfeat-morphological; Accuracy: 0.68
# Data set: mfeat-zernike; Accuracy: 0.74
# Data set: cmc; Accuracy: 0.52
# Data set: optdigits; Accuracy: 0.97
# Data set: credit-approval; Accuracy: 0.86
# Data set: credit-g; Accuracy: 0.75
# Data set: pendigits; Accuracy: 0.99
# Data set: diabetes; Accuracy: 0.76
# Data set: spambase; Accuracy: 0.94
# Data set: splice; Accuracy: 0.93
# Data set: tic-tac-toe; Accuracy: 0.94
# Data set: vehicle; Accuracy: 0.74
# Data set: electricity; Accuracy: 0.90
# Data set: satimage; Accuracy: 0.90
# Data set: eucalyptus; Accuracy: 0.66
# Data set: sick; Accuracy: 0.98
# Data set: vowel; Accuracy: 0.91
# Data set: isolet; Accuracy: 0.91
# Data set: analcatdata_authorship; Accuracy: 0.98
# Data set: analcatdata_dmft; Accuracy: 0.20
# Data set: mnist_784; Accuracy: 0.95
# Data set: pc4; Accuracy: 0.89
# Data set: pc3; Accuracy: 0.90
# Data set: jm1; Accuracy: 0.81
# Data set: kc2; Accuracy: 0.83
# Data set: kc1; Accuracy: 0.85
# Data set: pc1; Accuracy: 0.94
# Data set: adult; Accuracy: 0.85
# Data set: Bioresponse; Accuracy: 0.77
# Data set: wdbc; Accuracy: 0.96
# Data set: phoneme; Accuracy: 0.90
# Data set: qsar-biodeg; Accuracy: 0.86
# Data set: wall-robot-navigation; Accuracy: 0.99
# Data set: semeion; Accuracy: 0.88
# Data set: ilpd; Accuracy: 0.69
# Data set: madelon; Accuracy: 0.61
# Data set: nomao; Accuracy: 0.97
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/openml/tasks/functions.py in _get_cached_task(tid)
#      71     try:
# ---> 72         with io.open(os.path.join(tid_cache_dir, "task.xml"), encoding='utf8')\
#      73                 as fh:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Celina/.openml/cache/org/openml/www/tasks/9978/task.xml'
#
# During handling of the above exception, another exception occurred:
#
# OpenMLCacheException                      Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/openml/tasks/functions.py in _get_task_description(task_id)
#     385     try:
# --> 386         return _get_cached_task(task_id)
#     387     except OpenMLCacheException:
#
# //anaconda3/lib/python3.7/site-packages/openml/tasks/functions.py in _get_cached_task(tid)
#      78         raise OpenMLCacheException("Task file for tid %d not "
# ---> 79                                    "cached" % tid)
#      80
#
# OpenMLCacheException: Task file for tid 9978 not cached
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# //anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# //anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x12a88b668>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# //anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: /api/v1/xml/task/9978?api_key=c9ea8896542dd998ea42685f14e2bc14 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12a88b668>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-1db85f2c9a20> in <module>
#      16 for task_id in benchmark_suite.tasks:  # iterate over all tasks
#      17
# ---> 18     task = openml.tasks.get_task(task_id) # download the OpenML task
#      19     #X, y = task.get_X_and_y() # get the data (not used in this example)
#      20     openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
#
# //anaconda3/lib/python3.7/site-packages/openml/tasks/functions.py in get_task(task_id, download_data)
#     376             tid_cache_dir,
#     377         )
# --> 378         raise e
#     379
#     380     return task
#
# //anaconda3/lib/python3.7/site-packages/openml/tasks/functions.py in get_task(task_id, download_data)
#     358
#     359     try:
# --> 360         task = _get_task_description(task_id)
#     361         dataset = get_dataset(task.dataset_id, download_data)
#     362         # List of class labels availaible in dataset description
#
# //anaconda3/lib/python3.7/site-packages/openml/tasks/functions.py in _get_task_description(task_id)
#     394         )
#     395         task_xml = openml._api_calls._perform_api_call("task/%d" % task_id,
# --> 396                                                        'get')
#     397
#     398         with io.open(xml_file, "w", encoding='utf8') as fh:
#
# //anaconda3/lib/python3.7/site-packages/openml/_api_calls.py in _perform_api_call(call, request_method, data, file_elements)
#      49                              'are present')
#      50         return _read_url_files(url, data=data, file_elements=file_elements)
# ---> 51     return _read_url(url, request_method, data)
#      52
#      53
#
# //anaconda3/lib/python3.7/site-packages/openml/_api_calls.py in _read_url(url, request_method, data)
#      94         data['api_key'] = config.apikey
#      95
# ---> 96     response = send_request(request_method=request_method, url=url, data=data)
#      97     if response.status_code != 200:
#      98         raise _parse_server_exception(response, url)
#
# //anaconda3/lib/python3.7/site-packages/openml/_api_calls.py in send_request(request_method, url, data, files)
#     130             ) as e:
#     131                 if i == n_retries:
# --> 132                     raise e
#     133                 else:
#     134                     time.sleep(0.1 * i)
#
# //anaconda3/lib/python3.7/site-packages/openml/_api_calls.py in send_request(request_method, url, data, files)
#     117             try:
#     118                 if request_method == 'get':
# --> 119                     response = session.get(url, params=data)
#     120                 elif request_method == 'delete':
#     121                     response = session.delete(url, params=data)
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# //anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.openml.org', port=443): Max retries exceeded with url: /api/v1/xml/task/9978?api_key=c9ea8896542dd998ea42685f14e2bc14 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x12a88b668>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
import openml
import sklearn
from sklearn.neighbors import KNeighborsClassifier
import sklearn.pipeline
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

#openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
benchmark_suite = openml.study.get_suite('OpenML-CC18')  # obtain the benchmark suite

# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(),
                                     sklearn.neighbors.KNeighborsClassifier())

for task_id in benchmark_suite.tasks:  # iterate over all tasks

    task = openml.tasks.get_task(task_id) # download the OpenML task
    #X, y = task.get_X_and_y() # get the data (not used in this example)
    openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
    run = openml.runs.run_model_on_task(clf, task) # run classifier on splits (requires API key)
    score = run.get_metric_fn(sklearn.metrics.accuracy_score) # print accuracy score
    print('Data set: %s; Accuracy: %0.2f' % (task.get_dataset().name,score.mean()))
# Out:
# Data set: kr-vs-kp; Accuracy: 0.96
# Data set: letter; Accuracy: 0.95
# Data set: balance-scale; Accuracy: 0.84
# Data set: mfeat-factors; Accuracy: 0.95
# Data set: mfeat-fourier; Accuracy: 0.84
# Data set: breast-w; Accuracy: 0.97
# Data set: mfeat-karhunen; Accuracy: 0.97
# Data set: mfeat-morphological; Accuracy: 0.47
# Data set: mfeat-zernike; Accuracy: 0.82
# Data set: cmc; Accuracy: 0.51
# Data set: optdigits; Accuracy: 0.99
# Data set: credit-approval; Accuracy: 0.68
# Data set: credit-g; Accuracy: 0.66
# Data set: pendigits; Accuracy: 0.99
# Data set: diabetes; Accuracy: 0.72
# Data set: spambase; Accuracy: 0.81
# Data set: splice; Accuracy: 0.82
# Data set: tic-tac-toe; Accuracy: 0.83
# Data set: vehicle; Accuracy: 0.65
# Data set: electricity; Accuracy: 0.81
# Data set: satimage; Accuracy: 0.91
# Data set: eucalyptus; Accuracy: 0.48
# Data set: sick; Accuracy: 0.94
# Data set: vowel; Accuracy: 0.93
# Data set: isolet; Accuracy: 0.89
# Data set: analcatdata_authorship; Accuracy: 0.99
# Data set: analcatdata_dmft; Accuracy: 0.21

# %%
import openml
import sklearn
from sklearn.naive_bayes import GaussianNB
import sklearn.pipeline
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

#openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
benchmark_suite = openml.study.get_suite('OpenML-CC18')  # obtain the benchmark suite

# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(),
                                     sklearn.naive_bayes.GaussianNB())

for task_id in benchmark_suite.tasks:  # iterate over all tasks

    task = openml.tasks.get_task(task_id) # download the OpenML task
    #X, y = task.get_X_and_y() # get the data (not used in this example)
    openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
    run = openml.runs.run_model_on_task(clf, task) # run classifier on splits (requires API key)
    score = run.get_metric_fn(sklearn.metrics.accuracy_score) # print accuracy score
    print('Data set: %s; Accuracy: %0.2f' % (task.get_dataset().name,score.mean()))
