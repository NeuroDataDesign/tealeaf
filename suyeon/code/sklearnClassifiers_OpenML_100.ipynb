# %% [markdown]
# # Load in dataset

# %%
import openml
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

benchmark_suite = openml.study.get_suite('OpenML100')  # obtain the benchmark suite

# %% [markdown]
# # DecisionTreeClassifier

# %%
# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(), DecisionTreeClassifier())

for task_id in benchmark_suite.tasks:  # iterate over all tasks
    try:
        task = openml.tasks.get_task(task_id)  # download the OpenML task
        openml.config.apikey = '204cdba18d110fd68ad24b131ea92030'  # set the OpenML Api Key
        run = openml.runs.run_model_on_task(clf, task)  # run the classifier on the task
        score = run.get_metric_fn(sklearn.metrics.accuracy_score)  # print accuracy score
        print('Data set: %s; Accuracy: %0.2f' % (task.get_dataset().name,score.mean()))
    #     run.publish()  # publish the experiment on OpenML (optional, requires internet and an API key)
    #     print('URL for run: %s/run/%d' %(openml.config.server,run.run_id))
    except:
        print('Error in' + str(task_id))
# runs = openml.runs.list_runs(task=benchmark_suite.tasks, limit=1000)
# Out:
# Data set: kr-vs-kp; Accuracy: 1.00
# Data set: letter; Accuracy: 0.88
# Data set: balance-scale; Accuracy: 0.77
# Data set: mfeat-factors; Accuracy: 0.89
# Data set: mfeat-fourier; Accuracy: 0.74
# Data set: breast-w; Accuracy: 0.95
# Data set: mfeat-karhunen; Accuracy: 0.82
# Data set: mfeat-morphological; Accuracy: 0.65
# Data set: mfeat-pixel; Accuracy: 0.86
# Data set: car; Accuracy: 0.98
# Data set: mfeat-zernike; Accuracy: 0.67
# Data set: cmc; Accuracy: 0.48
# Data set: mushroom; Accuracy: 1.00
# Data set: optdigits; Accuracy: 0.90
# Data set: credit-approval; Accuracy: 0.81
# Data set: credit-g; Accuracy: 0.70
# Data set: pendigits; Accuracy: 0.96
# Data set: segment; Accuracy: 0.96
# Data set: diabetes; Accuracy: 0.70
# Data set: soybean; Accuracy: 0.93
# Data set: spambase; Accuracy: 0.92
# Data set: splice; Accuracy: 0.91
# Data set: tic-tac-toe; Accuracy: 0.88
# Data set: vehicle; Accuracy: 0.70
# Data set: waveform-5000; Accuracy: 0.75
# Data set: electricity; Accuracy: 0.89
# Data set: satimage; Accuracy: 0.86
# Data set: eucalyptus; Accuracy: 0.59
# Data set: sick; Accuracy: 0.99
# Data set: vowel; Accuracy: 0.83
# Data set: isolet; Accuracy: 0.82
# Data set: scene; Accuracy: 0.93
# Data set: monks-problems-1; Accuracy: 0.96
# Data set: monks-problems-2; Accuracy: 0.99
# Data set: monks-problems-3; Accuracy: 0.97
# Data set: JapaneseVowels; Accuracy: 0.88
# Data set: synthetic_control; Accuracy: 0.91
# Data set: irish; Accuracy: 1.00
# Data set: analcatdata_authorship; Accuracy: 0.93
# Data set: analcatdata_dmft; Accuracy: 0.21
# Data set: profb; Accuracy: 0.58
# Data set: collins; Accuracy: 1.00
# Data set: mnist_784; Accuracy: 0.88
# Data set: sylva_agnostic; Accuracy: 0.99
# Data set: gina_agnostic; Accuracy: 0.86
# Data set: ada_agnostic; Accuracy: 0.80
# Data set: mozilla4; Accuracy: 0.93
# Data set: pc4; Accuracy: 0.88
# Data set: pc3; Accuracy: 0.86
# Data set: jm1; Accuracy: 0.76
# Data set: kc2; Accuracy: 0.79
# Data set: kc1; Accuracy: 0.82
# Data set: pc1; Accuracy: 0.92
# Data set: KDDCup09_churn; Accuracy: 0.86
# Data set: KDDCup09_upselling; Accuracy: 0.91
# Data set: MagicTelescope; Accuracy: 0.82
# Data set: adult; Accuracy: 0.81
# Data set: wilt; Accuracy: 0.98
# Data set: wdbc; Accuracy: 0.93
# Data set: micro-mass; Accuracy: 0.77
# Data set: phoneme; Accuracy: 0.87
# Data set: one-hundred-plants-margin; Accuracy: 0.48
# Data set: one-hundred-plants-shape; Accuracy: 0.45
# Data set: one-hundred-plants-texture; Accuracy: 0.52
# Data set: qsar-biodeg; Accuracy: 0.82
# Data set: wall-robot-navigation; Accuracy: 0.99
# Data set: semeion; Accuracy: 0.75
# Data set: steel-plates-fault; Accuracy: 1.00
# Data set: tamilnadu-electricity; Accuracy: 1.00
# Data set: hill-valley; Accuracy: 0.55
# Data set: ilpd; Accuracy: 0.67
# Data set: madelon; Accuracy: 0.76
# Data set: nomao; Accuracy: 0.95
# Data set: ozone-level-8hr; Accuracy: 0.90
# Data set: cardiotocography; Accuracy: 1.00
# Data set: climate-model-simulation-crashes; Accuracy: 0.86
# Data set: cnae-9; Accuracy: 0.86
# Data set: eeg-eye-state; Accuracy: 0.84
# Data set: first-order-theorem-proving; Accuracy: 0.55
# Data set: gas-drift; Accuracy: 0.97
# Data set: banknote-authentication; Accuracy: 0.99
# Data set: blood-transfusion-service-center; Accuracy: 0.72
# Data set: artificial-characters; Accuracy: 0.95
# Data set: bank-marketing; Accuracy: 0.87
# Data set: Bioresponse; Accuracy: 0.74
# Data set: cjs; Accuracy: 0.99
# Data set: cylinder-bands; Accuracy: 0.73
# Data set: GesturePhaseSegmentationProcessed; Accuracy: 0.51
# Data set: har; Accuracy: 0.93
# Error in34536
# Data set: PhishingWebsites; Accuracy: 0.96
# Data set: MiceProtein; Accuracy: 1.00
# Data set: Amazon_employee_access; Accuracy: 0.93
# Data set: dresses-sales; Accuracy: 0.52
# Data set: LED-display-domain-7digit; Accuracy: 0.71
# Data set: texture; Accuracy: 0.93
# Data set: Australian; Accuracy: 0.82
# Data set: connect-4; Accuracy: 0.74
# Data set: higgs; Accuracy: 0.63
# Data set: SpeedDating; Accuracy: 0.79

# %% [markdown]
# # RandomForestClassifier

# %%
# build a scikit-learn classifier
clf = sklearn.pipeline.make_pipeline(sklearn.preprocessing.Imputer(),
                                     sklearn.ensemble.RandomForestClassifier())

for task_id in benchmark_suite.tasks:  # iterate over all tasks
    try:
        task = openml.tasks.get_task(task_id) # download the OpenML task
        #X, y = task.get_X_and_y() # get the data (not used in this example)
        openml.config.apikey = 'c9ea8896542dd998ea42685f14e2bc14'  # set the OpenML Api Key
        run = openml.runs.run_model_on_task(clf, task) # run classifier on splits (requires API key)
        score = run.get_metric_fn(sklearn.metrics.accuracy_score) # print accuracy score
        print('Data set: %s; Accuracy: %0.2f' % (task.get_dataset().name,score.mean()))
    except:
        print('Error in' + str(task_id))
# Out:
# Data set: kr-vs-kp; Accuracy: 0.99
# Data set: letter; Accuracy: 0.94
# Data set: balance-scale; Accuracy: 0.83
# Data set: mfeat-factors; Accuracy: 0.95
# Data set: mfeat-fourier; Accuracy: 0.79
# Data set: breast-w; Accuracy: 0.96
# Data set: mfeat-karhunen; Accuracy: 0.91
# Data set: mfeat-morphological; Accuracy: 0.70
# Data set: mfeat-pixel; Accuracy: 0.96
# Data set: car; Accuracy: 0.97
# Data set: mfeat-zernike; Accuracy: 0.75
# Data set: cmc; Accuracy: 0.52
# Data set: mushroom; Accuracy: 1.00
# Data set: optdigits; Accuracy: 0.97
# Data set: credit-approval; Accuracy: 0.86
# Data set: credit-g; Accuracy: 0.74
# Data set: pendigits; Accuracy: 0.99
# Data set: segment; Accuracy: 0.98
# Data set: diabetes; Accuracy: 0.74
# Data set: soybean; Accuracy: 0.94
# Data set: spambase; Accuracy: 0.94
# Data set: splice; Accuracy: 0.94
# Data set: tic-tac-toe; Accuracy: 0.93
# Data set: vehicle; Accuracy: 0.74
# Data set: waveform-5000; Accuracy: 0.81
# Data set: electricity; Accuracy: 0.89
# Data set: satimage; Accuracy: 0.90
# Data set: eucalyptus; Accuracy: 0.62
# Data set: sick; Accuracy: 0.98
# Data set: vowel; Accuracy: 0.92
# Data set: isolet; Accuracy: 0.90
# Data set: scene; Accuracy: 0.90
# Data set: monks-problems-1; Accuracy: 0.98
# Data set: monks-problems-2; Accuracy: 0.94
# Data set: monks-problems-3; Accuracy: 0.98
# Data set: JapaneseVowels; Accuracy: 0.95
# Data set: synthetic_control; Accuracy: 0.96
# Data set: irish; Accuracy: 1.00
# Data set: analcatdata_authorship; Accuracy: 0.98
# Data set: analcatdata_dmft; Accuracy: 0.21
# Data set: profb; Accuracy: 0.66
# Data set: collins; Accuracy: 0.80
# Data set: mnist_784; Accuracy: 0.95
# Data set: sylva_agnostic; Accuracy: 0.99
# Data set: gina_agnostic; Accuracy: 0.91
# Data set: ada_agnostic; Accuracy: 0.83
# Data set: mozilla4; Accuracy: 0.95
# Data set: pc4; Accuracy: 0.90
# Data set: pc3; Accuracy: 0.90
# Data set: jm1; Accuracy: 0.81
# Data set: kc2; Accuracy: 0.82
# Data set: kc1; Accuracy: 0.85
# Data set: pc1; Accuracy: 0.94
# Data set: KDDCup09_churn; Accuracy: 0.93
# Data set: KDDCup09_upselling; Accuracy: 0.94
# Data set: MagicTelescope; Accuracy: 0.87
# Data set: adult; Accuracy: 0.85
# Data set: wilt; Accuracy: 0.98
# Data set: wdbc; Accuracy: 0.95
# Data set: micro-mass; Accuracy: 0.82
# Data set: phoneme; Accuracy: 0.90
# Data set: one-hundred-plants-margin; Accuracy: 0.67
# Data set: one-hundred-plants-shape; Accuracy: 0.57
# Data set: one-hundred-plants-texture; Accuracy: 0.70
# Data set: qsar-biodeg; Accuracy: 0.85
# Data set: wall-robot-navigation; Accuracy: 0.99
# Data set: semeion; Accuracy: 0.88
# Data set: steel-plates-fault; Accuracy: 0.98
# Data set: tamilnadu-electricity; Accuracy: 0.99
# Data set: hill-valley; Accuracy: 0.55
# Data set: ilpd; Accuracy: 0.70
# Data set: madelon; Accuracy: 0.62
# Data set: nomao; Accuracy: 0.97
# Data set: ozone-level-8hr; Accuracy: 0.94
# Data set: cardiotocography; Accuracy: 1.00
# Data set: climate-model-simulation-crashes; Accuracy: 0.91
# Data set: cnae-9; Accuracy: 0.91
# Data set: eeg-eye-state; Accuracy: 0.90
# Data set: first-order-theorem-proving; Accuracy: 0.61
# Data set: gas-drift; Accuracy: 0.99
# Data set: banknote-authentication; Accuracy: 0.99
# Data set: blood-transfusion-service-center; Accuracy: 0.75
# Data set: artificial-characters; Accuracy: 0.92
# Data set: bank-marketing; Accuracy: 0.90
# Data set: Bioresponse; Accuracy: 0.77
# Data set: cjs; Accuracy: 0.76
# Data set: cylinder-bands; Accuracy: 0.78
# Data set: GesturePhaseSegmentationProcessed; Accuracy: 0.60
# Data set: har; Accuracy: 0.97
# Error in34536
# Data set: PhishingWebsites; Accuracy: 0.97
# Data set: MiceProtein; Accuracy: 0.99
# Data set: Amazon_employee_access; Accuracy: 0.94
# Data set: dresses-sales; Accuracy: 0.56
# Data set: LED-display-domain-7digit; Accuracy: 0.70
# Data set: texture; Accuracy: 0.97
# Data set: Australian; Accuracy: 0.86
# Data set: connect-4; Accuracy: 0.79
# Data set: higgs; Accuracy: 0.68
# Data set: SpeedDating; Accuracy: 0.85
